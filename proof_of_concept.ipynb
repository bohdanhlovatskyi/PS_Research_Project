# %%
import pandas as pd
import numpy as np
import os

# %%
os.listdir("./TMA")
# Out:
# ['codebook.txt', 'data.csv']

# %%
df = pd.read_csv("./TMA/data.csv")
df = df[df["age"] < 100]
df.head()
# Out:
#    score  gender  age  Q1  Q2  Q3  Q4  Q5  Q6  Q7  ...  Q41  Q42  Q43  Q44  \
# 0     32       2   56   2   2   2   1   2   1   2  ...    2    1    1    1
# 1     17       1   30   1   2   1   1   2   1   1  ...    1    1    2    2
# 2     41       1   32   2   1   1   2   1   1   1  ...    1    1    1    2
# 3     31       1   29   1   2   2   1   1   1   1  ...    1    2    1    1
# 4     35       1   23   1   2   2   1   1   2   1  ...    2    1    1    1
#
#    Q45  Q46  Q47  Q48  Q49  Q50
# 0    2    1    1    1    2    2
# 1    2    2    2    2    2    2
# 2    1    1    2    1    1    2
# 3    1    1    1    2    1    2
# 4    1    1    2    1    1    2
#
# [5 rows x 53 columns]

# %%
df.describe()
# Out:
#              score       gender          age           Q1           Q2  \
# count  5407.000000  5407.000000  5407.000000  5407.000000  5407.000000
# mean     32.325874     1.562419    30.126873     1.639171     1.601443
# std       9.465397     0.510106    11.898782     0.492080     0.505264
# min       0.000000     0.000000    14.000000     0.000000     0.000000
# 25%      27.000000     1.000000    21.000000     1.000000     1.000000
# 50%      34.000000     2.000000    27.000000     2.000000     2.000000
# 75%      39.000000     2.000000    36.000000     2.000000     2.000000
# max      50.000000     3.000000    94.000000     2.000000     2.000000
#
#                 Q3           Q4           Q5           Q6           Q7  ...  \
# count  5407.000000  5407.000000  5407.000000  5407.000000  5407.000000  ...
# mean      1.675606     1.472351     1.322915     1.204365     1.238950  ...
# std       0.480668     0.510999     0.480895     0.423412     0.445157  ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["score"])
# Out:
# (array([  30.,  101.,  183.,  300.,  427.,  725., 1033., 1285., 1005.,
#          318.]),
#  array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["age"])
# Out:
# (array([1.420e+03, 1.761e+03, 9.610e+02, 6.000e+02, 3.690e+02, 1.890e+02,
#         7.800e+01, 2.500e+01, 3.000e+00, 1.000e+00]),
#  array([14., 22., 30., 38., 46., 54., 62., 70., 78., 86., 94.]),
#  <BarContainer object of 10 artists>)

# %%
df.groupby(["age"])

# %%
plt.scatter(df["age"], [df[df["age"] == age]["score"].mean() for age in df["age"]])
